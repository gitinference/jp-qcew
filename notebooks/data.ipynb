# %%
import os
os.chdir("..")

# %%
import polars as pl
from src.data.data_process import cleanData

cd = cleanData()

# %%
df = cleanData().make_qcew_dataset()
df

# %%
df = cd.conn.sql("SELECT * FROM QCEWTable;").pl()
df
